# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Linear Regression</h1>

# %% [markdown]
# <h2>1. Linear Regression, one variable</h2>

# %%
x = np.arange(1, 11)

# Create random values for y
y = 10 + 3*x + 5*np.random.randn(10) + 10
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# Let $x = [x_1, x_2, \ldots, x_n]^T$ and $y = [y_1, y_2, \ldots, y_n]^T$.
#
# The design matrix $X$ contains two columns
# $$X = \begin{bmatrix}
# 1& x_1 \\
# 1& x_2 \\
# \vdots& \vdots \\
# 1& x_n
# \end{bmatrix}
# $$
# We can calculate the regression coefficients $M = [\theta_0, \theta_1]^T$ by
# $$M = (X^T X)^{-1} X^T y$$

# %%
# Design matrix X = [1 x]
X = np.concatenate((np.ones((10,1)), x.reshape(10,1)), axis=1)

# Target values y
Y = y.reshape((10,1))

# Calculate the regression coefficients
M = np.linalg.inv(np.dot(X.T, X)).dot(X.T).dot(Y)

z = X.dot(M)
plt.plot(x, z)
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# <h2>2. Regression, one variable, fitting a second order polynomial</h2>

# %% [markdown]
# We fit a second order model
# $$y_i = \theta_0 + \theta_1 x_i + \theta_2 x_i^2$$
# to the data. The design matrix $X$ now contains three columns
# $$X = \begin{bmatrix}
# 1& x_1& x_1^2 \\
# 1& x_2& x_2^2 \\
# \vdots& \vdots& \vdots \\
# 1& x_n& x_n^2
# \end{bmatrix}
# $$

# %%
X = np.concatenate((np.ones((10,1)), x.reshape(10,1), x.reshape(10,1)**2), axis=1)
Y = y.reshape((10,1))
M = np.linalg.inv(np.dot(X.T, X)).dot(X.T).dot(Y)

xx = np.linspace(1, 10, 1000)
XX = np.concatenate((np.ones((1000,1)), xx.reshape(1000,1), xx.reshape(1000,1)**2), axis=1)

yy = XX.dot(M)
plt.plot(xx, yy)
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# <h2>3. Fitting a higher order polynomial</h2>

# %% [markdown]
# We the use the Python command polyfit to fit a higher order polynomial
# $$y_i = \theta_0 + \theta_1 x_i + \theta_2 x_i^2 + \cdots + \theta_k x_i^k$$
# to the data.
#
# A 9th order polynomial has 10 parameters and can be made to fit the 10 datapoints perfectly.
# However, the polynomial often oscillates wildly between datapoints. It is therefore bad for estimating new values.
# This is called overfitting: the model learns the data very well, but is bad at predicting previously unseen values.
#
# Try yourself, how model behaves if you change the order $k$ of the polynomial in the command "polyfit(x, y, k)".

# %%
coef = np.polyfit(x, y, 9)
p = np.poly1d(coef)

xx = np.linspace(1, 10, 1000)
yy = p(xx)
plt.plot(x, y, 'o')
plt.plot(xx, yy)
plt.show()

# %% [markdown]
# <h2>4. Regression, multiple variables</h2>

# %% [markdown]
# We can use normal equations to fit a model, which explains a single target variable $y$ by several features $x^{(1)}, x^{(2)}, \ldots, x^{(m)}$. The model is
# $$y_i = \theta_0 + \theta_1 x^{(1)}_i + \theta_2 x^{(2)}_i + \cdots + \theta_m x^{(m)}_i$$
#
# We create a design matrix
# $$X = \begin{bmatrix}
# 1& x_1^{(1)}& x_1^{(2)}& \ldots& x_1^{(m)} \\
# 1& x_2^{(1)}& x_2^{(2)}& \ldots& x_2^{(m)} \\
# 1& x_3^{(1)}& x_3^{(2)}& \ldots& x_3^{(m)} \\
# \vdots& \vdots& \vdots&\ddots &\vdots \\
# 1& x_n^{(1)}& x_n^{(2)}& \ldots& x_n^{(m)}
# \end{bmatrix}
# $$
#
# The coefficients $M = [\theta_o \theta_1 \theta_2 \cdots \theta_m]^T$ can be calculated as above
# $$M = (X^T X)^{-1} X^T y$$

# %%
from tensorflow.contrib.tensorboard.plugins import projector
from keras.datasets import boston_housing

# Download the data

(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()


# Create the feature matrices

n = len(train_data)  # 404
m = len(test_data)  # 102

X = np.concatenate((np.ones((n, 1)), train_data), axis=1)
X_test = np.concatenate((np.ones((m, 1)), test_data), axis=1)


# Create target vectors

y = train_targets.reshape(n, 1)
y_test = test_targets.reshape(m, 1)

# Calculate the regression coefficients

M = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

y_estimate = X_test.dot(M)
results = np.concatenate((y_test, y_estimate, y_estimate - y_test), axis=1)
results
# Out:
# array([[  7.2       ,   9.69267239,   2.49267239],
#        [ 18.8       ,  21.05859431,   2.25859431],
#        [ 19.        ,  20.94145461,   1.94145461],
#        [ 27.        ,  34.25223414,   7.25223414],
#        [ 22.2       ,  25.95902598,   3.75902598],
#        [ 24.5       ,  20.56741038,  -3.93258962],
#        [ 31.2       ,  28.15310405,  -3.04689595],
#        [ 22.9       ,  25.07113862,   2.17113862],
#        [ 20.5       ,  20.30519458,  -0.19480542],
#        [ 23.2       ,  22.82489511,  -0.37510489],
#        [ 18.6       ,  20.29027213,   1.69027213],
#        [ 14.5       ,  18.07938917,   3.57938917],
#        [ 17.8       ,  16.46141024,  -1.33858976],
#        [ 50.        ,  35.31166595, -14.68833405],
#        [ 20.8       ,  19.41369959,  -1.38630041],
#        [ 24.3       ,  19.34727116,  -4.95272884],
#        [ 24.2       ,  24.58140904,   0.38140904],
#        [ 19.8       ,  21.01346252,   1.21346252],
#        [ 19.1       ,  19.99079236,   0.89079236],
#        [ 22.7       ,  23.79286427,   1.09286427],
#        [ 12.        ,  12.20780045,   0.20780045],
#        [ 10.2       ,  17.14218992,   6.94218992],
#        [ 20.        ,  22.51468752,   2.51468752],
#        [ 18.5       ,  12.92570511,  -5.57429489],
#        [ 20.9       ,  21.18070615,   0.28070615],
#        [ 23.        ,  23.94073547,   0.94073547],
#        [ 27.5       ,  33.46176314,   5.96176314],
#        [ 30.1       ,  24.2631555 ,  -5.8368445 ],
#        [  9.5       ,  13.35213096,   3.85213096],
#        [ 22.        ,  20.71939252,  -1.28060748],
#        [ 21.2       ,  23.45082103,   2.25082103],
#        [ 14.1       ,  19.1486881 ,   5.0486881 ],
#        [ 33.1       ,  36.09743765,   2.99743765],
#        [ 23.4       ,  23.47113531,   0.07113531],
#        [ 20.1       ,  19.03141995,  -1.06858005],
#        [  7.4       ,   5.92425733,  -1.47574267],
#        [ 15.4       ,  14.02090469,  -1.37909531],
#        [ 23.8       ,  22.96425377,  -0.83574623],
#        [ 20.1       ,  16.01731242,  -4.08268758],
#        [ 24.5       ,  27.09134249,   2.59134249],
#        [ 33.        ,  22.06997029, -10.93002971],
#        [ 28.4       ,  28.61755389,   0.21755389],
#        [ 14.1       ,  17.75679772,   3.65679772],
#        [ 46.7       ,  34.75579014, -11.94420986],
#        [ 32.5       ,  31.29455712,  -1.20544288],
#        [ 29.6       ,  24.73234165,  -4.86765835],
#        [ 28.4       ,  31.12655323,   2.72655323],
#        [ 19.8       ,  18.09268992,  -1.70731008],
#        [ 20.2       ,  22.62638989,   2.42638989],
#        [ 25.        ,  24.21208909,  -0.78791091],
#        [ 35.4       ,  30.5854317 ,  -4.8145683 ],
#        [ 20.3       ,  18.71860574,  -1.58139426],
#        [  9.7       ,  10.50163617,   0.80163617],
#        [ 14.5       ,  13.73779292,  -0.76220708],
#        [ 34.9       ,  34.4022841 ,  -0.4977159 ],
#        [ 26.6       ,  27.53140317,   0.93140317],
#        [  7.2       ,  18.08151522,  10.88151522],
#        [ 50.        ,  40.05101982,  -9.94898018],
#        [ 32.4       ,  37.63271513,   5.23271513],
#        [ 21.6       ,  24.64021422,   3.04021422],
#        [ 29.8       ,  25.73823434,  -4.06176566],
#        [ 13.1       ,  20.64369987,   7.54369987],
#        [ 27.5       ,  20.33514699,  -7.16485301],
#        [ 21.2       ,  21.38393124,   0.18393124],
#        [ 23.1       ,  24.63485497,   1.53485497],
#        [ 21.9       ,  23.53071805,   1.63071805],
#        [ 13.        ,  17.42141466,   4.42141466],
#        [ 23.2       ,  26.76911736,   3.56911736],
#        [  8.1       ,   3.83782148,  -4.26217852],
#        [  5.6       ,  11.97063636,   6.37063636],
#        [ 21.7       ,  24.2602519 ,   2.5602519 ],
#        [ 29.6       ,  23.67191799,  -5.92808201],
#        [ 19.6       ,  23.66639182,   4.06639182],
#        [  7.        ,   8.4403269 ,   1.4403269 ],
#        [ 26.4       ,  28.52690962,   2.12690962],
#        [ 18.9       ,  20.94071229,   2.04071229],
#        [ 20.9       ,  20.44489658,  -0.45510342],
#        [ 28.1       ,  24.77678169,  -3.32321831],
#        [ 35.4       ,  33.77299778,  -1.62700222],
#        [ 10.2       ,   7.02038331,  -3.17961669],
#        [ 24.3       ,  24.55379254,   0.25379254],
#        [ 43.1       ,  36.73923493,  -6.36076507],
#        [ 17.6       ,  16.09878612,  -1.50121388],
#        [ 15.4       ,  18.14663987,   2.74663987],
#        [ 16.2       ,  20.48899554,   4.28899554],
#        [ 27.1       ,  18.7928142 ,  -8.3071858 ],
#        [ 21.4       ,  22.45683561,   1.05683561],
#        [ 21.5       ,  26.19154506,   4.69154506],
#        [ 22.4       ,  23.36585592,   0.96585592],
#        [ 25.        ,  28.89583791,   3.89583791],
#        [ 16.6       ,  17.48243942,   0.88243942],
#        [ 18.6       ,  16.05642916,  -2.54357084],
#        [ 22.        ,  26.69532678,   4.69532678],
#        [ 42.8       ,  28.1393996 , -14.6606004 ],
#        [ 35.1       ,  35.04164989,  -0.05835011],
#        [ 21.5       ,  20.05308052,  -1.44691948],
#        [ 36.        ,  36.25269116,   0.25269116],
#        [ 21.9       ,  38.51475052,  16.61475052],
#        [ 24.1       ,  25.13506119,   1.03506119],
#        [ 50.        ,  41.49062194,  -8.50937806],
#        [ 26.7       ,  34.65500235,   7.95500235],
#        [ 25.        ,  25.33950895,   0.33950895]])

# %%
print('Linear regression mean absolute error:', np.sum(np.abs(y_estimate - y_test))/m)
# Out:
# Linear regression mean absolute error: 3.4641858124070257
